# %%
# %%sql
# -- AUTO REFRESH: Power BI detects Lakehouse changes automatically
# -- Force table refresh metadata
# REFRESH TABLE gold_ai_production;
# REFRESH TABLE silver_budget;
# REFRESH TABLE bronze_erp;
# Out:
# StatementMeta(, 3b4f8d35-ba78-43ac-b1ef-4369ac874ace, 11, Finished, Available, Finished)
# <Spark SQL result set with 0 rows and 0 fields>
# <Spark SQL result set with 0 rows and 0 fields>
# <Spark SQL result set with 0 rows and 0 fields>
